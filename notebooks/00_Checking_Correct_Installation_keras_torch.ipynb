# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tensorchiefs/dl_course_2025/blob/main/notebooks/00_Checking_Correct_Installation_keras_torch.ipynb)
#
#
# ### Checking your installation
#
# If you run Keras & Pytorch locally:
#
#
#
# Please check that the notebook below runs smoothly.
#
# https://keras.io/getting_started/
#
# PyTorch compatibility
# The following Keras + PyTorch versions are compatible with each other:
#
# torch~=2.1.0 & keras~=3.0

# %% [markdown]
# #CPU only
# pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cpu
#
# #Cuda11.8
# pip install torch==2.1.0+cu118 torchvision==0.16.0+cu118 torchaudio==2.1.0+cu118 --index-url https://download.pytorch.org/whl/cu118
#
# #CUDA12.1
# pip install torch==2.1.0+cu121 torchvision==0.16.0+cu121 torchaudio==2.1.0+cu121 --index-url https://download.pytorch.org/whl/cu121
#
# # keras
# pip install keras==3.0.0

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
import keras

# %%
import torch
torch.__version__

# %%
torch.Tensor([1,2,3]) #Should print (tensor([1., 2., 3.]))

# %%
import numpy as np
np.__version__ #Should work < 2.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(range(100), np.sin(0.1 * np.array(range(100))))
#Should work and plot a sine wave
